# %% [markdown]
# <a href="https://colab.research.google.com/github/jorgenriquez/Inteligencia_artificial/blob/main/Clase_02_Inteligencia_artificial.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![cabezote_ia.png](data:image/png;base64,...)

# %% [markdown]
# # Unidad 2. Introducción a Python
#
# Herramientas para graficos en Machine Learning
#
#
# *   Matplotlib
# *   Seaborn

# %% [markdown]
# # **Matplotlib**
# [
# https://matplotlib.org/](https://)
#
# Matplotlib es una biblioteca completa para crear visualizaciones estáticas, animadas e interactivas en Python. Matplotlib hace que las cosas fáciles sean fáciles y las difíciles posibles.
#
#
# *   Cree gráficos con calidad de publicación.
# *   Crea figuras interactivas que puedan hacer zoom, desplazarse y actualizarse
#
# *   Personalice el estilo visual y el diseño.
#
# *   Exporte a muchos formatos de archivo.
# *   Incrustar en JupyterLab y en interfaces gráficas de usuario.
#
# *   Incrustar en JupyterLab y en interfaces gráficas de usuario.
#
#
# *   Utilice una amplia gama de paquetes de terceros creados en Matplotlib.
#
# ### **Instalación**
# `!pip install matplotlib`
#
# `!conda install -c conda-forge matplotlib`

# %% [markdown]
# ## Import

# %%
import matplotlib
import matplotlib.pyplot as plt

# %%
# Muestrar los gráficos integrados dentro de jupyter notebook
# %matplotlib inline

# %% [markdown]
# ## Representación gráfica de datos

# %% [markdown]
# Si a la función de trazado se le da una matriz de datos, la usará como coordenadas en el eje vertical, y utilizará el índice de cada punto de datos en el array como la coordenada horizontal.

# %%
plt.plot([1, 2, 5, 7, 8, 3, 1])
plt.show()

# %% [markdown]
# También se puede proporcionar dos matrices: una para el eje horizontal, y otra para el eje vertical.

# %%
plt.plot([-3, -1, 0, 4, 7], [1, 4, 6, 7, 8])
plt.show()

# %% [markdown]
# Pueden modificarse las logitudes de los ejes para que la figura no se vea tan ajustada

# %%
plt.plot([-3, -1, 0, 4, 7], [1, 4, 6, 7, 8])
plt.axis([-4, 8, 0, 10]) # [xmin, xmax, ymin, ymax]
plt.show()

# %% [markdown]
# Se sigue el mismo procedimiento para pintar una función matemática

# %%
import numpy as np
x = np.linspace(-2, 2, 500)
y = x**2

plt.plot(x, y)
plt.show()

# %% [markdown]
# También pude modificarse el estilo de la gráfica para que contenga más información.

# %%
plt.plot(x, y)
plt.title("Square function")
plt.xlabel("x")
plt.ylabel("y = x**2")
plt.grid(True)
plt.show()

# %% [markdown]
# Pueden superponerse gráficas y cambiar el estilo de las líneas

# %%
import numpy as np
x = np.linspace(-2, 2, 500)
y = x**2
y2 = x + 1

plt.plot(x, y, 'b--', x, y2, 'g')
plt.show()

# %%
# Separando en diferentes lineas las funciones
import numpy as np
x = np.linspace(-2, 2, 500)
y = x**2
y2 = x + 1

plt.plot(x, y, 'b--')
plt.plot(x, y2, 'g')
plt.show()

# %% [markdown]
# Para poder diferenciar entre ambas funciones siempre es recomendable añadir una leyenda

# %%
import numpy as np
plt.figure(figsize=(8,6)) # Que tan grande queremos el espacio de trabajo
x = np.linspace(-2, 2, 500)
y = x**2
y2 = x + 1
plt.plot(x, y, 'b--', label="x**2")
plt.plot(x, y2, 'g', label="x+1")
plt.title(" Division del espacio de trabajo")
plt.xlabel("X")
plt.ylabel("Y")
plt.legend(loc="best") # La situa en la mejor localización
plt.show()

# %% [markdown]
# Tambien puede crearse dos graficas que no se superpongan. Estas graficas se organizan en un grid y se denominan subplots.

# %%
import numpy as np
x = np.linspace(-2, 2, 500)
y = x**2
y2 = x + 1
y3 = x**3
y4 = - x**2

plt.subplot(1, 2, 1) # 1 rows, 1 columns, 1st subplot
plt.plot(x, y, 'b--')

plt.subplot(1, 2, 2) # 1 rows, 2 columns, 2nd subplot
plt.plot(x, y2, 'g')

plt.show()

# %% [markdown]
# Para que las gráficas no queden tan ajustadas, podemos hacer la figura más grande.

# %%
x = np.linspace(-2, 2, 500) # Dividir la pantalla en varios subplot
y1 = x**2
y2 = x + 1
y3 = x**3
y4 = - x**2

plt.figure(figsize=(10,8)) # Que tan grande queremos el espacio de trabajo


plt.subplot(2, 2, 1) # 1 rows, 1 columns, 1st subplot
plt.plot(x, y, 'b--')
plt.xlabel("x1", fontsize=14)
plt.ylabel("y1", fontsize=14)

plt.subplot(2, 2, 2) # 1 rows, 2 columns, 2nd subplot
plt.plot(x, y2, 'g')
plt.xlabel("x2", fontsize=14)
plt.ylabel("y2", fontsize=14)

plt.subplot(2, 2, 3) # 1 rows, 2 columns, 2nd subplot
plt.plot(x, y3, 'g')
plt.xlabel("x3", fontsize=14)
plt.ylabel("y3", fontsize=14)

plt.subplot(2, 2, 4) # 1 rows, 2 columns, 2nd subplot
plt.plot(x, y4, 'g')
plt.xlabel("x4", fontsize=14)
plt.ylabel("y4", fontsize=14)

plt.show()
# Out:
# <ipython-input-92-78a5807cb69b>:10: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   plt.subplot(2, 2, 1) # 1 rows, 1 columns, 1st subplot

# %% [markdown]
# ## Scatter plots

# %%
from numpy.random import rand
x, y = rand(2, 100)
plt.scatter(x, y)
plt.show()

# %%
from numpy.random import rand
x, y = rand(2, 100)
x2, y2 = rand(2, 100)
plt.scatter(x, y, c='red')
plt.scatter(x2, y2, c='blue')
plt.show()

# %% [markdown]
# ## Histogramas
#
# La función hist permite crear histogramas en Python al utilizar matplotlib. Para crear un histograma básico tan solo es necesario pasar una variable numérica a la función.

# %%
data = [1, 1.1, 1.8, 2, 2.1, 3.2, 3, 3, 3, 3]
plt.subplot(211) # 2 rows, 1 columns, 1st subplot
plt.hist(data, bins = 10, rwidth=0.8)

plt.subplot(212) # 2 rows, 1 columns, 2nd subplot
plt.hist(data, bins = [1, 1.5, 2, 2.5, 3], rwidth=0.95)
plt.xlabel("Value")
plt.ylabel("Frequency")

plt.show()

# %% [markdown]
# **Histograma horizontal**
#
# Estableciendo el argumento orientation como "horizontal" puedes rotar los ejes y crear un histograma horizontal.

# %%
# Semilla para reproducibilidad

np.random.seed(4)

# Simulación de datos
x = np.random.normal(0, 1, 100)

# Histograma
plt.figure(figsize=(14,6))
fig, ax = plt.subplots()
ax.hist(x, orientation = "horizontal")
plt.show()

# %% [markdown]
# ### Número de clases
#
# El número por defecto de clases (bins) de un histograma hecho con la función `hist` es 10. Sin embargo, esto puede que no sea la mejor opción para todos los conjuntos de datos. En este escenario, puedes utilizar el argumento `bins` para elegir un número de clases más adecuado o establecer un método de selección. Los métodos de selección disponibles son '`auto`', '`fd`', '`doane`', '`scott`', '`stone`', '`rice`', '`sturges`' (el utilizado por defecto en el lenguaje de programación R) y 'sqrt'.

# %%
# Semilla para reproducibilidad
np.random.seed(6)

# Simulación de datos
x = np.random.normal(0, 1, 500)

# Histograma (demasiadas clases)
fig, ax = plt.subplots()
ax.hist(x, bins = 60)
plt.show()

# %% [markdown]
# ### Histogramas por grupos
#
#
# También puedes crear un histograma con varios grupos con la función. Para ello tan solo es necesario pasar una lista con varios conjuntos de datos, como en el ejemplo siguiente. Por defecto, las barras de los grupos se mostrarán una al lado de las otras.

# %%
# Semilla para reproducibilidad
np.random.seed(4)

# Simulación de datos
x1 = np.random.normal(0, 1, 100)
x2 = np.random.normal(0, 1, 100)
x = [x1, x2]

# Histograma
fig, ax = plt.subplots()
ax.hist(x)
plt.show()
# plt.show()

# %% [markdown]
# ### Histogramas “barstacked”
#
# El método "`barstacked`" apila las barras cuando hay varios grupos. Este tipo de histograma también se puede crear con `stacked = True.`

# %%
# Semilla para reproducibilidad
np.random.seed(4)

# Simulación de datos
x = np.random.normal(0, 1, 100)

# Histograma
fig, ax = plt.subplots()
ax.hist(x, histtype = "step")
# plt.show()
# Out:
# (array([ 2.,  4., 14., 11., 17., 24., 16.,  4.,  4.,  4.]),
#  array([-2.37977527, -1.89413933, -1.40850339, -0.92286744, -0.4372315 ,
#          0.04840444,  0.53404039,  1.01967633,  1.50531227,  1.99094822,
#          2.47658416]),
#  [<matplotlib.patches.Polygon at 0x7f5570396fe0>])

# %% [markdown]
# ### Histograma  “stepfilled”
#
# El último método disponible es el método "`stepfilled`", que es lo mismo que "`step`" pero con color de relleno. Si tienes un grupo mostrará lo mismo que el tipo por defecto, pero si tienes varios grupos se solaparán uno sobre otro, como en el ejemplo siguiente.

# %%
# Semilla para reproducibilidad
np.random.seed(4)

# Simulación de datos
x1 = np.random.normal(0, 1, 100)
x2 = np.random.normal(0, 1, 100)
x = [x1, x2]

# Histograma
fig, ax = plt.subplots()
ax.hist(x, histtype = "stepfilled")
# plt.show()
# Out:
# (array([[ 2.,  4., 14., 11., 17., 24., 16.,  4.,  4.,  4.],
#         [ 2.,  5., 10., 13., 24., 16., 14.,  8.,  5.,  3.]]),
#  array([-2.37977527, -1.89413933, -1.40850339, -0.92286744, -0.4372315 ,
#          0.04840444,  0.53404039,  1.01967633,  1.50531227,  1.99094822,
#          2.47658416]),
#  <a list of 2 list[Polygon] objects>)

# %%
plt.style.use('_mpl-gallery')

# make data
x = np.arange(0, 10, 2)
ay = [1, 1.25, 2, 2.75, 3]
by = [1, 1, 1, 1, 1]
cy = [2, 1, 2, 1, 2]
y = np.vstack([ay, by, cy])

# plot
fig, ax = plt.subplots()

ax.stackplot(x, y)

ax.set(xlim=(0, 8), xticks=np.arange(1, 8),
       ylim=(0, 8), yticks=np.arange(1, 8))

plt.show()

# %% [markdown]
# ## Array

# %%
"""
======================
streamplot(X, Y, U, V)
======================

See `~matplotlib.axes.Axes.streamplot`.
"""
import matplotlib.pyplot as plt
import numpy as np

plt.style.use('_mpl-gallery-nogrid')

# make a stream function:
X, Y = np.meshgrid(np.linspace(-3, 3, 256), np.linspace(-3, 3, 256))
Z = (1 - X/2 + X**5 + Y**3) * np.exp(-X**2 - Y**2)
# make U and V out of the streamfunction:
V = np.diff(Z[1:, :], axis=1)
U = -np.diff(Z[:, 1:], axis=0)

# plot:
fig, ax = plt.subplots()

ax.streamplot(X[1:, 1:], Y[1:, 1:], U, V)

plt.show()

# %% [markdown]
# ## Trazar series temporales
# Aquí trazamos la serie temporal, agregamos etiquetas, título y una pequeña anotación sobre el origen de los datos. Usando la barra de herramientas de la izquierda puede ampliar los datos para ver, por ejemplo, el calentamiento y enfriamiento día/noche. También puede desplazarse a lo largo de la serie temporal utilizando el icono de cuatro flechas. Tenga en cuenta que como hemos dicho sharex=Trueal crear los ejes, la ventana de tiempo permanece conectada en ambos sero de tiempo.

# %% [markdown]
# Dataset es tomado de  https://www.ncei.noaa.gov/pub/data/uscrn/products/hourly02/ y es la temperatura horaria y la radiación solar en Dinosaur, Colorado.
#
# Este ejemplo es tomdao de la pagina oficial de matplotlib: https://mybinder.org/v2/gh/matplotlib/mpl-brochure-binder/main?labpath=MatplotlibExample.ipynb

# %%
#   Note the use of datetimes in the file complicate loading a bit.
#   We recommend using pandas or xarray for more elegant solutions
#   to handling complex timeseries data.
with open('/content/small.txt', 'r') as f:
    data = np.genfromtxt(f, dtype='datetime64[s],f,f,f',
                         names=['date', 'doy', 'temp', 'solar'])
datetime = data['date']
dayofyear = data['doy']
temperature = data['temp']
solar = data['solar']

# make two-day smoothed versions:
temp_low = np.convolve(temperature, np.ones(48)/48, mode='same')
solar_low = np.convolve(solar, np.ones(48)/48, mode='same')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-69-028d214f17e3> in <cell line: 4>()
#       2 #   We recommend using pandas or xarray for more elegant solutions
#       3 #   to handling complex timeseries data.
# ----> 4 with open('/content/small.txt', 'r') as f:
#       5     data = np.genfromtxt(f, dtype='datetime64[s],f,f,f',
#       6                          names=['date', 'doy', 'temp', 'solar'])
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/small.txt'

# %%
fig, (ax0, ax1) = plt.subplots(2, 1, sharex=True, constrained_layout=True)

# temperature:
ax0.plot(datetime, temperature, label='hourly')
ax0.plot(datetime, temp_low, label='smoothed')
ax0.legend(loc='upper right')
ax0.set_ylabel('Temperature $[^oC]$')  # note the use of TeX math formatting

# solar-radiation:
ax1.plot(datetime, solar, label='hourly')
ax1.plot(datetime, solar_low, label='smoothed')
ax1.legend(loc='upper right')
ax1.set_ylabel('Solar radiation $[W\,m^{-2}]$')   # note the use of TeX math formatting

ax0.set_title('Observations: Dinosaur, Colorado', loc='left')
ax0.text(0.03, 0.03, 'https://www.ncei.noaa.gov/pub/data/uscrn/products/hourly02/',
         fontsize='small', fontstyle='italic', transform=ax0.transAxes);

# %% [markdown]
# ## Guardar las figuras

# %%
import numpy as np
x = np.linspace(-2, 2, 500)
y = x**2
y2 = x + 1

plt.plot(x, y, 'b--', label="x**2")
plt.plot(x, y2, 'g', label="x+1")
plt.legend(loc="best")
plt.savefig("mi_grafica.png", transparent=True)

# %% [markdown]
# ## Graficos en 3D

# %%
"""
==============
3D scatterplot
==============

See `~mpl_toolkits.mplot3d.axes3d.Axes3D.scatter`.
"""
import matplotlib.pyplot as plt
import numpy as np

plt.style.use('_mpl-gallery')

# Make data
np.random.seed(19680801)
n = 100
rng = np.random.default_rng()
xs = rng.uniform(23, 32, n)
ys = rng.uniform(0, 100, n)
zs = rng.uniform(-50, -25, n)

# Plot
fig, ax = plt.subplots(subplot_kw={"projection": "3d"})
ax.scatter(xs, ys, zs)

ax.set(xticklabels=[],
       yticklabels=[],
       zticklabels=[])

plt.show()

# %%
"""
=====================
3D surface
=====================

See `~mpl_toolkits.mplot3d.axes3d.Axes3D.plot_surface`.
"""
import matplotlib.pyplot as plt
from matplotlib import cm
import numpy as np

plt.style.use('_mpl-gallery')

# Make data
X = np.arange(-5, 5, 0.25)
Y = np.arange(-5, 5, 0.25)
X, Y = np.meshgrid(X, Y)
R = np.sqrt(X**2 + Y**2)
Z = np.sin(R)

# Plot the surface
fig, ax = plt.subplots(subplot_kw={"projection": "3d"})
ax.plot_surface(X, Y, Z, vmin=Z.min() * 2, cmap=cm.Blues)

ax.set(xticklabels=[],
       yticklabels=[],
       zticklabels=[])

plt.show()

# %%
"""
======================
Triangular 3D surfaces
======================

See `~mpl_toolkits.mplot3d.axes3d.Axes3D.plot_trisurf`.
"""
import matplotlib.pyplot as plt
from matplotlib import cm
import numpy as np

plt.style.use('_mpl-gallery')

n_radii = 8
n_angles = 36

# Make radii and angles spaces
radii = np.linspace(0.125, 1.0, n_radii)
angles = np.linspace(0, 2*np.pi, n_angles, endpoint=False)[..., np.newaxis]

# Convert polar (radii, angles) coords to cartesian (x, y) coords.
x = np.append(0, (radii*np.cos(angles)).flatten())
y = np.append(0, (radii*np.sin(angles)).flatten())
z = np.sin(-x*y)

# Plot
fig, ax = plt.subplots(subplot_kw={'projection': '3d'})
ax.plot_trisurf(x, y, z, vmin=z.min() * 2, cmap=cm.Blues)

ax.set(xticklabels=[],
       yticklabels=[],
       zticklabels=[])

plt.show()

# %% [markdown]
# ## **Seaborn: visualización de datos estadísticos**
# Seaborn es una biblioteca de visualización de datos de Python basada en matplotlib . Proporciona una interfaz de alto nivel para dibujar gráficos estadísticos atractivos e informativos.
#
# Para obtener una breve introducción a las ideas detrás de la biblioteca, puede leer las notas introductorias o el artículo . Visite la página de instalación para ver cómo puede descargar el paquete y comenzar con él. Puede explorar la galería de ejemplos para ver algunas de las cosas que puede hacer con seaborn y luego consultar los tutoriales o la referencia de API para descubrir cómo hacerlo.
#
# Para ver el código o informar un error, visite el repositorio de GitHub . Las preguntas de soporte general se encuentran más a gusto en stackoverflow , que tiene un canal dedicado para seaborn.
#
# https://seaborn.pydata.org/
#
# **Instalación**
#
# Las versiones oficiales de seaborn se pueden instalar desde PyPI :
#
# `pip install seaborn`
#
# `conda install seaborn`
#
# `conda install seaborn -c conda-forge`

# %% [markdown]
# **Inicio rápido**

# %%
import seaborn as sns
df = sns.load_dataset("penguins")
sns.pairplot(df, hue="species")

# %%
# Lo ideal es al iniciar cualquier proyecto de Machine Laerning cargar todas las librerias
import numpy as np
import pandas as pd

import matplotlib as mpl
import matplotlib.pyplot as plt

import seaborn as sns
import seaborn.objects as so

# %% [markdown]
# # **Ejemplos con la base de datos  "iris"**

# %%
# loading dataset
data = sns.load_dataset("iris")

# draw lineplot
sns.lineplot(x="sepal_length", y="sepal_width", data=data)

# %% [markdown]
# **Usando Seaborn con Matplotlib**
#
# Usar Matplotlib y Seaborn juntos es un proceso muy simple. Solo tenemos que invocar la función Seaborn Plotting como de costumbre, y luego podremos usar la función de personalización de Matplotlib.

# %%
# Ejemplo 1: usaremos el ejemplo anterior y agregaremos el título al gráfico usando Matplotlib.

# importing packages
import seaborn as sns
import matplotlib.pyplot as plt

# loading dataset
data = sns.load_dataset("iris")

# draw lineplot
sns.lineplot(x="sepal_length", y="sepal_width", data=data)

# setting the title using Matplotlib
plt.title('Title using Matplotlib Function')

plt.show()

# %%
# Ejemplo 2: configuración de xlim e ylim

# importing packages
import seaborn as sns
import matplotlib.pyplot as plt
fig, axes = plt.subplots(1,1, figsize=(10,8))

# loading dataset
data = sns.load_dataset("iris")

# draw lineplot
sns.lineplot(x="sepal_length", y="sepal_width", data=data)

# setting the x limit of the plot
plt.xlim(5)

plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
fig, axes = plt.subplots(1,1, figsize=(10,8))

tips = sns.load_dataset("tips")

# customize the scatter plot

sns.scatterplot(x="total_bill", y="tip", hue="sex", size="size", sizes=(50, 200), data=tips)

# add labels and title

plt.xlabel("Total Bill")

plt.ylabel("Tip")

plt.title("Relationship between Total Bill and Tip")

# display the plot
plt.show()

# %%
import seaborn as sns

fmri = sns.load_dataset("fmri")

sns.lineplot(x="timepoint", y="signal", data=fmri)

# %% [markdown]
# ### **Diagrama de barras**
#
# Un diagrama de barras se utiliza básicamente para agregar datos categóricos de acuerdo con algunos métodos y, de forma predeterminada, es la media. También puede entenderse como una visualización del grupo por acción. Para usar este gráfico, elegimos una columna categórica para el eje x y una columna numérica para el eje y y vemos que crea un gráfico tomando una media por columna categórica. Se puede crear utilizando el método barplot() .

# %%
# importing packages
import seaborn as sns
import matplotlib.pyplot as plt

fig, axes = plt.subplots(1,1, figsize=(8,6))

# loading dataset
data = sns.load_dataset("iris")

sns.barplot(x='species', y='sepal_length', data=data)
plt.show()

# %% [markdown]
# ### **Diagrama de caja**
#
#
# Un diagrama de caja se conoce a veces como diagrama de caja y bigotes. Muestra la distribución de los datos cuantitativos que representan las comparaciones entre variables. El diagrama de caja muestra los cuartiles del conjunto de datos, mientras que los bigotes se extienden para mostrar el resto de la distribución, es decir, los puntos que indican la presencia de valores atípicos. Se crea utilizando el método boxplot() .
#
# ![image.png](data:image/png;base64,...)
#
#
# Un diagrama de caja es una poderosa herramienta de visualización de datos que se utiliza para comprender la distribución de los datos. Divide los datos en cuartiles y los resume en función de cinco números derivados de estos cuartiles:
#
# **mediana:** el valor medio de los datos. marcado como Q2, representa el percentil 50.
#
# **primer cuartil:**  el valor medio entre “mínimo no atípico” y mediana. marcado como Q1, representa el percentil 25.
#
#
# **tercer cuartil:** el valor medio entre el “máximo no atípico” y la mediana. marcado como Q3, representa el percentil 75.
#
#
# **“valor no atípico máximo”:**  calculado por (Q3 + 1,5*IQR). Todos los valores por encima de este se consideran valores atípicos.
#
# **“valor mínimo no atípico”:** calculado por (Q1 – 1,5*IQR). Todos los valores por debajo de este se consideran valores atípicos.

# %%
# importing packages
import seaborn as sns
import matplotlib.pyplot as plt
fig, axes = plt.subplots(1,1, figsize=(8,6))

# loading dataset
data = sns.load_dataset("iris")

sns.boxplot(x='species', y='sepal_width', data=data)
plt.show()

# %% [markdown]
# ### **Violinplot**
#
# Es similar al diagrama de caja, excepto que proporciona una visualización más alta y avanzada y utiliza la estimación de la densidad del núcleo para brindar una mejor descripción de la distribución de los datos. Se crea utilizando el método violinplot() .

# %%
# importing packages
import seaborn as sns
import matplotlib.pyplot as plt
fig, axes = plt.subplots(1,1, figsize=(8,6))
# loading dataset
data = sns.load_dataset("iris")

sns.violinplot(x='species', y='sepal_width', data=data)
plt.show()

# %% [markdown]
# ### **Distplot**
#
# Distplot se usa básicamente para un conjunto univariante de observaciones y lo visualiza a través de un histograma, es decir, solo una observación y, por lo tanto, elegimos una columna particular del conjunto de datos. Se encapsula utilizando el método distplot().

# %%
# importing packages
import seaborn as sns
import matplotlib.pyplot as plt

# loading dataset
data = sns.load_dataset("iris")

sns.distplot(data['sepal_width'])
plt.show()

# %% [markdown]
# ### **Diagrama de pares**
#
#
# Pairplot representa una relación por pares en todo el marco de datos y admite un argumento adicional llamado tono para la separación categórica. Básicamente, lo que hace es crear una gráfica conjunta entre cada columna numérica posible y lleva un tiempo si el marco de datos es realmente enorme. Se traza utilizando el método pairplot() .

# %%
# importing packages
import seaborn as sns
import matplotlib.pyplot as plt

# loading dataset
data = sns.load_dataset("iris")

sns.pairplot(data=data, hue='species')
plt.show()

# %% [markdown]
# ### **Gráficos de regresión**
#
# Los gráficos de regresión tienen como objetivo principal agregar una guía visual que ayude a enfatizar patrones en un conjunto de datos durante los análisis de datos exploratorios. Los gráficos de regresión, como su nombre indica, crean una línea de regresión entre dos parámetros y ayudan a visualizar sus relaciones lineales.

# %% [markdown]
# **lmplot**
#
# El método lmplot() puede entenderse como una función que básicamente crea un gráfico de modelo lineal. Crea un diagrama de dispersión con un ajuste lineal encima.

# %%
# importing packages
import seaborn as sns
import matplotlib.pyplot as plt

# loading dataset
data = sns.load_dataset("tips")

sns.lmplot(x='total_bill', y='tip', data=data)
plt.show()

# %% [markdown]
# **regplo**
#
# El método regplot() también es similar a lmplot, que crea un modelo de regresión lineal.

# %%
# importing packages
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(8, 6))

# loading dataset
data = sns.load_dataset("tips")

sns.regplot(x='total_bill', y='tip', data=data)
plt.show()

# %%
# import the necessary python packages
import pandas as pd
import seaborn as sns
import numpy as np

plt.figure(figsize=(10, 8))

# read the dataset using pandas read_csv
# function
data = pd.read_csv("/content/tips.csv")

data.head()

# create a bar plot by specifying
# x and y axis and the data to be used.
ax = sns.barplot(x='time', y='tip',
				hue='sex', data=data,
				errwidth=0)

# sns.barplot method will return a list of
# sub methods use containers method to access
# the text label of each bar by passing it
# through the ax.bar_label function use for
# loop to iterate through the list of
# labels and assign each bar to a different
# label.
for i in ax.containers:
	ax.bar_label(i,)
