# %% [markdown]
# <a href="https://colab.research.google.com/github/jorgenriquez/Inteligencia_artificial/blob/main/sentencias.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![cabezote programación con Python.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# **Jorge Enrique Chaparro Mesa**
#
# Profesor Facultad de Ingeniería UNITROPICO.
#
# PhD(c) en Ingeniería Electrónica y de Computación. UdeA

# %% [markdown]
# # **Sentencias If, Elif y Else**

# %% [markdown]
# ## **Sentencias If, Elif y Else**
#
# La estructura ` if/elif/else` es una forma común de controlar el flujo de un programa, lo que te permite ejecutar bloques de código específicos según el valor de algunos datos.
#
# ## **Sentencia if**
#
# Si la condición que sigue a la palabra clave `if` se evalúa como verdadera, el bloque de código se ejecutará. Ten en cuenta que los paréntesis no se utilizan antes y después de la verificación de condición como en otros idiomas.
#
# ![Captura.PNG](data:image/png;base64,...)

# %% [markdown]
# ```
# if condicion:
#     # ejecutar un código
# ```
# **En la expresión anterior:**
#
# 1.   La condición es una expresión booleana que se evalúa como verdadera `(True)` o falsa `(False)`.
# 2.   Se requiere el uso de dos puntos `(:)` al final de la condición.-
# 1.   Todas las líneas de código a ejecutar si se cumple la condición tienen que estar indentadas respecto la sentencia `if`.
#
# La indentación es una característica que diferencia Python de otros lenguajes de programación, dónde el código a ejecutar de cumplirse la condición se encierra entre llaves. Esta característica tiene el propósito de mejorar la legibilidad de los programas.

# %%
if True:
  print('¡el bloque If se ejecutará!')
# Out:
# ¡el bloque If se ejecutará!

# %%
# Entrada definicion de las variables
X = 7

# %%
# Proceso y salida
if X >= 5:
  print("¡La condición era verdadera!") #Esta sentencia se ejecuta
  print("¡La condición era verdadera!") #Esta sentencia se ejecuta
  print("¡La condición era verdadera!") #Esta sentencia se ejecuta
  print("¡La condición era verdadera!") #Esta sentencia se ejecuta
  print("¡La condición era verdadera!") #Esta sentencia se ejecuta
# Out:
# ¡La condición era verdadera!
# ¡La condición era verdadera!
# ¡La condición era verdadera!
# ¡La condición era verdadera!
# ¡La condición era verdadera!

# %%
temperature = 67

if temperature >= 35:
  print("Aviso por alta temperatura")
# Out:
# Aviso por alta temperatura

# %% [markdown]
# ## **Sentencia else**
# A la sentencia if se le puede añadir opcionalmente una sentencia` else`. Esta sentencia contiene el código a ejecutar en caso de que no se cumpla la condición de la sentencia `if`. Esta estructura se expresa del siguiente modo:
#
#
# ```
# if condicion verdadera:
#     # ejecutar un código
# else:
#     # ejecutar un código distinto
# ```
#
#
#
# ![else.PNG](data:image/png;base64,...)

# %%
if False:
  print('¡La sentencia If se ejecutará!')
else:
  print('¡La sentencia Else se ejecutará!')
# Out:
# ¡La sentencia Else se ejecutará!

# %%
y = 2

# %%
if y >= 4:
  print("¡No voy a imprimir!") #esta sentencia no se ejecuta
else:
  print("¡La condición no era verdadera!") #esta sentencia se ejecuta
# Out:
# ¡La condición no era verdadera!

# %%
x = 10
if x >= 10:
  print('x es mayor o igual que 10')
else:
  print('x es menor o igual que 10')
# Out:
# x es mayor o igual que 10

# %% [markdown]
# ### **Condiciones anidadas**

# %%
#temperature = input("Digite un valor de temperatura: ")
# temperature = float(temperature)  # Convierte la entrada a un número decimal

temperature = 9

if temperature < 20:
  if temperature < 10:
    print("Nivel azul")
  else:
    print("Nivel verde")
else:
  if temperature < 30:
    print("Nivel naranja")
  else:
    print("Nivel rojo")
# Out:
# Nivel azul

# %% [markdown]
# ## **Sentencia elif**
#
# Se pueden verificar varias condiciones al incluir una o más verificaciones `elif` después de su declaración `if `inicial. A una sentencia` if` `else` se pueden añadir un número indefinido de condiciones adicionales a verificar. Estas condiciones se definen mediante la sentencia `elif` , la cual es un abreviación de `else if`. Ésta se define así:
#
# ![image.png](data:image/png;base64,...)
#
#
# ```
# if condicion:
#     # ejecutar un código
# elif otra_condicion:
#     # ejecutar otro código
# else:
#     # ejecutar un código distinto
# ```

# %%
z = 9
if z > 8:
  print("¡No voy a imprimir!") # esta sentencia no se ejecuta
  print("¡No voy a imprimir!") # esta sentencia no se ejecuta
  print("¡No voy a imprimir!") # esta sentencia no se ejecuta
  print("¡No voy a imprimir!") # esta sentencia no se ejecuta
  print("¡No voy a imprimir!") # esta sentencia no se ejecuta

elif z > 5:
  print("¡Yo lo haré!") #esta sentencia se ejecuta
elif z > 6:
  print("¡Tampoco voy a imprimir!") #esta sentencia no se ejecuta
else:
  print("¡Yo tampoco!") #esta sentencia no se ejecuta
# Out:
# ¡No voy a imprimir!
# ¡No voy a imprimir!
# ¡No voy a imprimir!
# ¡No voy a imprimir!
# ¡No voy a imprimir!

# %%
x = 10
if x > 10:
    print('x es mayor que 10')
elif x < 10:
    print('x es menor que 10')
else:
    print('x es 10')
# Out:
# x es 10

# %%
# Asignación de valor inicial
temperature = 5

# Condicionales

if temperature < 20:
  if temperature < 10:
    print("Nivel azul")
  else:
    print("Nivel verde")
elif temperature < 30:
  print("Nivel naranja")
else:
  print("Nivel rojo")
# Out:
# Nivel azul

# %%
temperature = 29

if temperature < 20:
  if temperature < 10:
    print("Nivel azul")
  else:
    print("Nivel verde")
else:
  if temperature < 30:
    print("Nivel naranja")
  else:
    print("Nivel rojo")
# Out:
# Nivel naranja

# %% [markdown]
# ## **Asignaciones condicionales**
#
# Supongamos que queremos asignar un nivel de riesgo de incendio en función de la
# temperatura. En su versión clásica escribiríamos:

# %%
temperature = 35

if temperature < 30:
  el_nivel_es = "LOW"
else:
  el_nivel_es = "HIGH"
el_nivel_es
# Out:
# 'HIGH'

# %%
# Otra Forma
el_nivel_es = "LOW" if temperature < 30 else "HIGH"
el_nivel_es
# Out:
# 'HIGH'

# %% [markdown]
# ## **Operadores de comparación**
# Cuando escribimos condiciones debemos incluir alguna expresión de comparación. Para usar estas expresiones es fundamental conocer los operadores que nos ofrece Python:

# %% [markdown]
# \begin{array}{|l|l|}
# \hline \text { Operador } & \text { Símbolo } \\
# \hline \text { Igualdad } & == \\
# \hline \text { Desigualdad } & != \\
# \hline \text { Menor que } & < \\
# \hline \text { Menor o igual que } & <= \\
# \hline \text { Mayor que } & > \\
# \hline \text { Mayor o igual que } & >= \\
# \hline
# \end{array}

# %%
# Asignación de valor inicial
value = 9
value == 9
# Out:
# True

# %%
value != 8
# Out:
# True

# %%
value < 12
# Out:
# True

# %%
value <= 7
# Out:
# True

# %% [markdown]
# ## **Operadores lógicos**
# Podemos escribir condiciones más complejas usando los operadores lógicos:
# * and
# *or
# *not

# %%
# Asignación de valor inicial
x = 3
((x > 1) or (x > 6)) and (not(x > 10)) # True or False
# Out:
# True

# %%
x = 6
(x > 7) and (x < 12) or (not(x >= 3))
# Out:
# False

# %%
x > 4 and x > 12 # True and False
# Out:
# False

# %%
(x > 4) and (x < 12) # True and True
# Out:
# False

# %%
x = 4
not(x != 8) # not False
# Out:
# False

# %%
# NOT Negador
x = 3
(x > 2)
not(x>2)
# Out:
# False

# %%
# Ingresar el año
year = int(input("Ingrese un año: "))

# Comprobar si años es bisiesto
if (year / 4 == 0 and year / 100 == 0) or year / 400 == 0:
    print(f"{year} es un año bisiesto.")
else:
    print(f"{year} no es un año bisiesto.")
# Out:
# Ingrese un año: 2000
# 2000 no es un año bisiesto.

# %% [markdown]
# # **Bucles**
#
# Existen distintos tipos de bucles en programación. Mientras que otros lenguajes tienen hasta tres tipos de loops distintos, Python cuenta con dos tipos de bucles fundamentales:
#
# https://docs.python.org/es/3/tutorial/controlflow.html#for-statements
#
# ## **Bucles For**
# Los bucles `for` se basan en iteradores que recorren todos los elementos de aquellos objetos que sean iterables: listas, tuplas, cadenas. Ejecuta una pieza de código repetidamente en función de la cantidad de elementos que contenga el objeto iterable.
#
# Un bucle for establece la variable iteradora en cada valor de una lista, arreglo o cadena proporcionada y repite el código en el cuerpo del bucle for para cada valor de la variable iteradora.
#
# En el ejemplo a continuación, usamos un bucle for para imprimir cada número de nuestro arreglo.

# %%
# Ejemplo bucle for
lista =  [1, 2, 3, 4]
for i in lista:
    print(i, end=", ") # prints: 1, 2, 3, 4,
# Out:
# 1, 2, 3, 4,

# %%
# Ejemplo bucle for
lista =  [1, 2, 3, 4]
for i in lista:
    print(i)
# Out:
# 1
# 2
# 3
# 4

# %%
word = "Python"
for i in word:
  print(i, end=", ") # prints: 1, 2, 3, 4,
# Out:
# P, y, t, h, o, n,

# %%
# Measure some strings:
words = ['cat', 'window', 'defenestrate']
for w in words:
    print(w, len(w))
# Out:
# cat 3
# window 6
# defenestrate 12

# %%
# Measure some strings:
words = ['cat', 'window', 'defenestrate']
for w in words:
    print(w)
# Out:
# cat
# window
# defenestrate

# %%
# Measure some strings:
words = {'cat:4', 'window: 23', 'defenestrate:75'}
for w in words:
    print(w, len(w))
# Out:
# cat:4 5
# window: 23 10
# defenestrate:75 15

# %% [markdown]
# Cuando los valores de un arreglo para nuestro bucle for son secuenciales, podemos usar la función range() de Python en lugar de escribir el contenido de nuestro arreglo.
#
# ### **La función range() en Python**
# La función range() proporciona una secuencia de enteros basada en los argumentos de la función. Se puede encontrar información adicional en la documentación de Python para la función range().
#
#
# ```
# range(parar)
# range(incio, paraor[, pas])
# ```

# %%
# Ejemplo con un argumento
for i in range(3):
    print(i, end=", ") # prints: 0, 1, 2, 3, 4,
# Out:
# 0, 1, 2,

# %%
# Ejemplo con un argumento
for i in range(5):
    print(i) # prints: 0, 1, 2, 3, 4,
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
# Ejemplo con dos argumentos
for i in range(-1, 5):
    print(i, end=", ") #
# Out:
# -1, 0, 1, 2, 3, 4,

# %% [markdown]
# Para iterar sobre los índices de una secuencia, puedes combinar range() y len() así:

# %%
a = ['Mary', 'had', 'a', 'little', 'lamb']
for i in range(len(a)):
    print(i, a[i], end=", ")
# Out:
# 0 Mary, 1 had, 2 a, 3 little, 4 lamb,

# %% [markdown]
# ## **Romper un bucle for**

# %%
word = "Python"
for i in word:
  if i == "t":
    break
  print(i)
# Out:
# P
# y

# %% [markdown]
# # Bucle for en diccionarios
# Un caso es especial de bucle for se da al recorrer los elementos de un diccionario. Dado que un diccionario está compuesto por pares clave/valor, hay distintas formas de iterar sobre ellas.
#
# 1 – Recorrer las claves del diccionario.

# %%
valores = {'A': 4, 'E': 3, 'I': 1, 'O': 0}
for k in valores:
    print(k)
# Out:
# A
# E
# I
# O

# %% [markdown]
# 2 – Iterar sobre los valores del diccionario

# %%
valores = {'A': 4, 'E': 3, 'I': 1, 'O': 0}
for v in valores.values():
    print(v)
# Out:
# 4
# 3
# 1
# 0

# %% [markdown]
# 3 – Iterar a la vez sobre la clave y el valor de cada uno de los elementos del diccionario.

# %%
valores = {'A': 4, 'E': 3, 'I': 1, 'O': 0}
for k, v in valores.items():
    print('k=', k, ', v=', v)
# Out:
# k= A , v= 4
# k= E , v= 3
# k= I , v= 1
# k= O , v= 0

# %%
# Iterar sobre los valores de una lista o tupla
A = ["hola", 1, 65, "gracias", [2, 3]]
for value in A:
    print(value)
# Out:
# hola
# 1
# 65
# gracias
# [2, 3]

# %%
#  Iterar sobre claves en un diccionario (también conocido como hashmap)

fruta_a_color = {"manzana": "#ff0000",
                 "lima": "#ffff00",
                 "naranja": "#ffa500"}

for key in fruta_a_color:
    print(key, fruta_a_color[key])
# Out:
# manzana #ff0000
# lima #ffff00
# naranja #ffa500

# %% [markdown]
# Iterar sobre dos listas del mismo tamaño en un solo bucle con la función zip()

# %%
A = ["a", "b", "c"]
B = ["a", "d", "e"]

for a, b in zip(A, B):
  print (a, b, a == b)
# Out:
# a a True
# b d False
# c e False

# %% [markdown]
# Iterarar sobre una lista y obtener el índice correspondiente con la función enumerate() - enumerar

# %%
A = ["esto", "es", "algo", "divertido"]

for indice,palabra in enumerate(A):
    print(indice, palabra)
# Out:
# 0 esto
# 1 es
# 2 algo
# 3 divertido

# %% [markdown]
# ## **for … else**
# En relación al apartado anterior, Python ofrece una estructura adicional de bucle for cuya estructura es la siguiente:
# for e in iterable:
#     # Tu código aquí
# else:
#     # Este código siempre se ejecuta si no
#     # se ejecutó la sentencia break en el bloque for

# %%
numeros = [1, 2, 4, 5, 8, 6]

for n in numeros:
    if n == 69:
        break
else:
    print('No se encontró el número 3')
# Out:
# No se encontró el número 3

# %% [markdown]
# ## **Bucles While**
# Los bucles o loops while ejecutan los bloques de código a los que afecta siempre y cuando la condición del bucle sea verdadera.
#
# El bucle while se repite hasta que la condición se ha cumplido un numero determinado de veces.
#
# La semántica tras esta sentencia es: `**Mientras se cumpla la condición haz algo**`
# *Es similar a la función if, sin embargo, el bucle while en Python se ejecuta varias veces mientras que los if tan solo se ejecutan una vez*.
#
# https://www.freecodecamp.org/espanol/news/python-tutorial-ciclos-while/
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Analicemos este proceso en más detalle:
#
# * El proceso inicia cuando se encuentra un ciclo while durante la ejecución del programa.
# * Se evalúa la condición para determinar si es verdadera o falsa (`True o False`).
# * Si la condición es verdadera (`True`), la secuencia de instrucciones o sentencias que pertenecen al ciclo while se ejecutan.
# * Nuevamente se evalúa y verifica la condición del ciclo while.
# * Si la condición es verdadera (`True`) nuevamente, la secuencia de instrucciones en el cuerpo del ciclo while se ejecutan y el proceso se repite.
# * Cuando la condición es falsa (`False`), el ciclo se detiene y el programa continúa más allá del ciclo while.
#
# Una de las características más importantes de los ciclos while es que las variables usadas en la condición del ciclo no se actualizan automáticamente.
#
# Nosotros tenemos que actualizar sus valores explícitamente en nuestro código para asegurarnos de que el ciclo se detendrá en algún momento, cuando la condición sea falsa (`False`).

# %% [markdown]
# **Esta es la sintaxis básica:**
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Estos son los elementos principales (en orden):
#
# La palabra clave while (seguida de un espacio).
#
# *   Ua condicnión que determina si el ciclo continuará su ejecución o no en base a su valor (True o False).
# *   Elemento de listaDos puntos (:) al final de la primera línea.
# *   La secuencia de instrucciones o sentencias que se repetirán.
# *   A este bloque de código se le denomina el "cuerpo" del ciclo y debe estar indentado.
# *  Si una línea de código no está indentada, no se considerará parte del ciclo.
#
# ![image.png](data:image/png;base64,...)

# %%
i = 4
while i < 8:
    print(i)
    i += 2 # Incremental
# Out:
# 4
# 6

# %%
#i = 10
#while i >= 10:
  #print('x es mayor o igual que 10')

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# Definimos la lista
nums = []

# El ciclo se ejecutará mientras el tamaño (length)
# de la lista nums sea menor que 4.=
while len(nums) < 4:
    # Le pedimos al usuario que ingrese un valor y lo guardamos en una variable como un número entero
    valor_ingresado = int(input("Ingrese un numero entero: "))
    # Si el valor es un número par, lo agregamos a la lista
    if valor_ingresado % 2 == 0:
        nums.append(valor_ingresado)
# Out:
# Ingrese un numero entero: 4
# Ingrese un numero entero: 5
# Ingrese un numero entero: 6
# Ingrese un numero entero: 2
# Ingrese un numero entero: 4
